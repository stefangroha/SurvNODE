# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

from lifelines import CoxPHFitter
from lifelines import KaplanMeierFitter

from pycox.evaluation import EvalSurv
from sklearn.preprocessing import StandardScaler

# %%
random_seed = 137
torch.manual_seed(random_seed)
np.random.seed(random_seed)

use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

print(device)
# Out:
# cuda:0

# %%
# Early stopping class from https://github.com/Bjarten/early-stopping-pytorch
from SurvNODE.EarlyStopping import EarlyStopping
from SurvNODE.SurvNODE_x_ranking import *

# %%
def measures(odesurv,initial,x,Tstart,Tstop,From,To,trans,status, multiplier=1.,points=500):
    with torch.no_grad():
        time_grid = np.linspace(0, multiplier, points)
        pvec = torch.zeros((points,x.shape[0]))
        surv_ode = odesurv.predict(x,torch.from_numpy(np.linspace(0,multiplier,points)).float().to(x.device))
        pvec = torch.einsum("ilkj,k->ilj",(surv_ode[:,:,:,:],initial))[:,:,0].cpu()
        pvec = np.array(pvec.cpu().detach())
        surv_ode_df = pd.DataFrame(pvec)
        surv_ode_df.loc[:,"time"] = np.linspace(0,multiplier,points)
        surv_ode_df = surv_ode_df.set_index(["time"])
        ev_ode = EvalSurv(surv_ode_df, np.array(Tstop.cpu()), np.array(status.cpu()), censor_surv='km')
        conc = ev_ode.concordance_td('antolini')
        ibs = ev_ode.integrated_brier_score(time_grid)
        inbll = ev_ode.integrated_nbll(time_grid)
    return conc,ibs,inbll

# %%
from sklearn_pandas import DataFrameMapper
import pandas as pd

def make_dataloader(df,Tmax,batchsize):
#     cols_standardize = ['x0', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13']
#     cols_leave = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6']

#     standardize = [([col], StandardScaler()) for col in cols_standardize]
#     leave = [(col, None) for col in cols_leave]
#     x_mapper = DataFrameMapper(standardize + leave)
#     X = x_mapper.fit_transform(df).astype('float32')

    X = df[['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8']].values
    
    X = torch.from_numpy(X).float().to(device)
    T = torch.from_numpy(df[["duration"]].values).float().flatten().to(device)
    T = T/Tmax
    T[T==0] = 1e-8
    E = torch.from_numpy(df[["event"]].values).float().flatten().to(device)

    Tstart = torch.from_numpy(np.array([0 for i in range(T.shape[0])])).float().to(device)
    From = torch.tensor([1],device=device).repeat((T.shape))
    To = torch.tensor([2],device=device).repeat((T.shape))
    trans = torch.tensor([1],device=device).repeat((T.shape))

    dataset = TensorDataset(X,Tstart,T,From,To,trans,E)
    loader = DataLoader(dataset, batch_size=batchsize, shuffle=True)
    return loader

# %%
from sklearn.model_selection import train_test_split

def odesurv_manual_benchmark(df_train, df_test,config,name):
    torch.cuda.empty_cache()
    df_train, df_val = train_test_split(df_train, test_size=0.2, stratify=df_train.loc[:,"event"])
    
    Tmax = df_train["duration"].max()
    
    train_loader = make_dataloader(df_train,Tmax/config["multiplier"],int(len(df_train)*config["batch_size"]))
    val_loader = make_dataloader(df_val,Tmax/config["multiplier"],len(df_val))
    test_loader = make_dataloader(df_test,Tmax/config["multiplier"],len(df_test))
    
    num_in = 9
    num_latent = config["num_latent"]
    layers_encoder =  [config["encoder_neurons"]]*config["num_encoder_layers"]
    dropout_encoder = [config["encoder_dropout"]]*config["num_encoder_layers"]
    layers_odefunc =  [config["odefunc_neurons"]]*config["num_odefunc_layers"]

    trans_matrix = torch.tensor([[np.nan,1],[np.nan,np.nan]]).to(device)

    encoder = Encoder(num_in,num_latent,layers_encoder, dropout_encoder).to(device)
    odefunc = ODEFunc(trans_matrix,num_in,num_latent,layers_odefunc,config["softplus_beta"]).to(device)
    block = ODEBlock(odefunc).to(device)
    odesurv = SurvNODE(block,encoder).to(device)

    optimizer = torch.optim.Adam(odesurv.parameters(), weight_decay = config["weight_decay"], lr=config["lr"])
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=config["scheduler_gamma"], patience=config["scheduler_epoch"])

    early_stopping = EarlyStopping(name=name,patience=config["patience"], verbose=True)
    for i in tqdm(range(1000)):
        odesurv.train()
        for mini,ds in enumerate(train_loader):
            myloss,_,_ = loss(odesurv,*ds,mu=config["mu"],alpha=config["alpha"],sigma=config["sigma"])
            optimizer.zero_grad()
            myloss.backward()    
            optimizer.step()

        
        odesurv.eval()
        with torch.no_grad():
            lossval,conc,ibs,ibnll = 0., 0., 0., 0.
            for _,ds in enumerate(val_loader):
                t1,_,_ = loss(odesurv,*ds,mu=config["mu"],alpha=config["alpha"],sigma=config["sigma"])
                lossval += t1.item()
                t1,t2,t3 = measures(odesurv,torch.tensor([1.,0.],device=device),*ds,multiplier=config["multiplier"])
                conc += t1
                ibs += t2
                ibnll += t3
            early_stopping(lossval/len(val_loader), odesurv)
            scheduler.step(lossval/len(val_loader))
            
            conc_test,ibs_test,ibnll_test = 0., 0., 0.
            print("it: "+str(i)+", train loss="+str(myloss.item())+", validation loss="+str(lossval/len(val_loader))+", c="+str(conc/len(val_loader))+", ibs="+str(ibs/len(val_loader))+", ibnll="+str(ibnll/len(val_loader)))

        if early_stopping.early_stop:
            print("Early stopping")
            break

    odesurv.load_state_dict(torch.load(name+'_checkpoint.pt'))

    odesurv.eval()
    with torch.no_grad():
        conc,ibs,ibnll = 0., 0., 0.
        for _,ds in enumerate(test_loader):
            t1,t2,t3 = measures(odesurv,torch.tensor([1.,0.],device=device),*ds,multiplier=config["multiplier"])
            conc += t1
            ibs += t2
            ibnll += t3
    return conc/len(test_loader), ibs/len(test_loader), ibnll/len(test_loader)

# %%
from sklearn.model_selection import StratifiedKFold
from pycox import datasets

kfold = StratifiedKFold(5, shuffle=True)
df_all = datasets.metabric.read_df()
gen = kfold.split(df_all.iloc[:,df_all.columns.values!="event"],df_all.loc[:,"event"])

config = {
    "lr": 1e-3,
    "weight_decay": 1e-3,
    "num_latent": 200,
    "encoder_neurons": 50,
    "num_encoder_layers": 4,
    "encoder_dropout": 0.,
    "odefunc_neurons": 800,
    "num_odefunc_layers": 2,
    "batch_size": 1/3,
    "multiplier": 1.,
    "mu": 1e-1,
    "alpha": 0.7,
    "sigma": 0.1,
    "softplus_beta": 1.,
    "scheduler_epoch": 10,
    "scheduler_gamma": 0.1,
    "patience": 20
}

odesurv_bench_vals = []
for g in gen:
    df_train = df_all.iloc[g[0]]
    df_test =  df_all.iloc[g[1]]
    conc, ibs, ibnll = odesurv_manual_benchmark(df_train,df_test,config,"metabric_test")
    odesurv_bench_vals.append([conc,ibs,ibnll])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Validation loss decreased (inf --> 0.161452).  Saving model ...
# it: 0, train loss=0.7617104649543762, validation loss=0.16145195066928864, c=0.5354734029015017, ibs=0.181363949950862, ibnll=0.5383163511823669
# EarlyStopping counter: 1 out of 20
# it: 1, train loss=0.5374631881713867, validation loss=0.24406588077545166, c=0.5509671672181217, ibs=0.18134758631652412, ibnll=0.5395845425523068
# EarlyStopping counter: 2 out of 20
# it: 2, train loss=0.39296647906303406, validation loss=0.3268198072910309, c=0.5474357342835328, ibs=0.18127056306803127, ibnll=0.5390520197884567
# EarlyStopping counter: 3 out of 20
# it: 3, train loss=0.16378892958164215, validation loss=0.207983136177063, c=0.5682425553575974, ibs=0.18010064108857227, ibnll=0.5366584958962884
# EarlyStopping counter: 4 out of 20
# it: 4, train loss=0.19430136680603027, validation loss=0.1715567409992218, c=0.5686243318910664, ibs=0.18165707215164492, ibnll=0.5396820362383445
# EarlyStopping counter: 5 out of 20
# it: 5, train loss=0.17162925004959106, validation loss=0.1675759255886078, c=0.5698014762025961, ibs=0.18023890833198036, ibnll=0.536866775132894
# Validation loss decreased (0.161452 --> 0.159683).  Saving model ...
# it: 6, train loss=0.15832427144050598, validation loss=0.15968257188796997, c=0.5706604734029015, ibs=0.18474682364499218, ibnll=0.5478526976890609
# Validation loss decreased (0.159683 --> 0.146040).  Saving model ...
# it: 7, train loss=0.13700510561466217, validation loss=0.14604026079177856, c=0.5687515907355561, ibs=0.1799190561923658, ibnll=0.5355491862108571
# EarlyStopping counter: 1 out of 20
# it: 8, train loss=0.13412334024906158, validation loss=0.15207907557487488, c=0.5689742937134131, ibs=0.18409161294935708, ibnll=0.5440132569780294
# Validation loss decreased (0.146040 --> 0.136100).  Saving model ...
# it: 9, train loss=0.12703166902065277, validation loss=0.1360999494791031, c=0.573332909137185, ibs=0.17760018435800937, ibnll=0.5307898229636935
# Validation loss decreased (0.136100 --> 0.135503).  Saving model ...
# it: 10, train loss=0.12266267836093903, validation loss=0.13550260663032532, c=0.5766416390939171, ibs=0.1772372522669487, ibnll=0.5298430056898055
# Validation loss decreased (0.135503 --> 0.127695).  Saving model ...
# it: 11, train loss=0.1374291628599167, validation loss=0.1276947408914566, c=0.5765461949605497, ibs=0.17962052247518767, ibnll=0.5336755540003087
# EarlyStopping counter: 1 out of 20
# it: 12, train loss=0.11273054033517838, validation loss=0.1377331018447876, c=0.5820819546958513, ibs=0.17606978209748078, ibnll=0.5262720129190196
# EarlyStopping counter: 2 out of 20
# it: 13, train loss=0.12997618317604065, validation loss=0.128996342420578, c=0.587172308475439, ibs=0.1755475728325267, ibnll=0.525033678907313
# Validation loss decreased (0.127695 --> 0.126036).  Saving model ...
# it: 14, train loss=0.11054039746522903, validation loss=0.12603555619716644, c=0.5894629676762535, ibs=0.17603586854439943, ibnll=0.5253532230130863
# Validation loss decreased (0.126036 --> 0.120755).  Saving model ...
# it: 15, train loss=0.117280513048172, validation loss=0.12075500935316086, c=0.5939488419445151, ibs=0.17547462534661232, ibnll=0.5238583975164569
# EarlyStopping counter: 1 out of 20
# it: 16, train loss=0.11845798790454865, validation loss=0.12208832055330276, c=0.5992937134130822, ibs=0.17425557428412586, ibnll=0.5216182657470269
# Validation loss decreased (0.120755 --> 0.116701).  Saving model ...
# it: 17, train loss=0.11156177520751953, validation loss=0.11670103669166565, c=0.6013616696360397, ibs=0.17429049267465777, ibnll=0.5207432880482811
# Validation loss decreased (0.116701 --> 0.112124).  Saving model ...
# it: 18, train loss=0.1073528528213501, validation loss=0.11212432384490967, c=0.6097607533723594, ibs=0.17279812115850493, ibnll=0.5174242201183245
# EarlyStopping counter: 1 out of 20
# it: 19, train loss=0.10674060136079788, validation loss=0.11321532726287842, c=0.6113833036396029, ibs=0.17348839605075794, ibnll=0.5184548851922408
# Validation loss decreased (0.112124 --> 0.109082).  Saving model ...
# it: 20, train loss=0.11011217534542084, validation loss=0.10908161103725433, c=0.6166963603970476, ibs=0.17235657864449586, ibnll=0.5157554695399098
# EarlyStopping counter: 1 out of 20
# it: 21, train loss=0.10661585628986359, validation loss=0.11978736519813538, c=0.6189552048867396, ibs=0.172195038165536, ibnll=0.515050723359647
# EarlyStopping counter: 2 out of 20
# it: 22, train loss=0.11690670251846313, validation loss=0.11860118061304092, c=0.6243318910664292, ibs=0.17354525963427256, ibnll=0.5179737946364713
# EarlyStopping counter: 3 out of 20
# it: 23, train loss=0.10291015356779099, validation loss=0.1199386864900589, c=0.6280860269788751, ibs=0.17279701328551925, ibnll=0.5161123633718767
# EarlyStopping counter: 4 out of 20
# it: 24, train loss=0.0988583117723465, validation loss=0.11344189941883087, c=0.6351807075591753, ibs=0.171714238197867, ibnll=0.5134641584274608
# EarlyStopping counter: 5 out of 20
# it: 25, train loss=0.10429555177688599, validation loss=0.1170303076505661, c=0.6382667345380504, ibs=0.17142608797051656, ibnll=0.5126437898950262
# Validation loss decreased (0.109082 --> 0.103774).  Saving model ...
# it: 26, train loss=0.1010093092918396, validation loss=0.10377377271652222, c=0.6416072792059048, ibs=0.17115728521276813, ibnll=0.5120649298041372
# Validation loss decreased (0.103774 --> 0.103671).  Saving model ...
# it: 27, train loss=0.10374058783054352, validation loss=0.10367139428853989, c=0.6540786459658946, ibs=0.1707212031838747, ibnll=0.5118621662085887
# EarlyStopping counter: 1 out of 20
# it: 28, train loss=0.11955559998750687, validation loss=0.10823758691549301, c=0.6503563247645712, ibs=0.1728393286628593, ibnll=0.516233038851953
# Validation loss decreased (0.103671 --> 0.098365).  Saving model ...
# it: 29, train loss=0.09461215138435364, validation loss=0.09836483001708984, c=0.6532196487655892, ibs=0.17046840465414512, ibnll=0.510562104935441
# EarlyStopping counter: 1 out of 20
# it: 30, train loss=0.08306650072336197, validation loss=0.11857149749994278, c=0.644629676762535, ibs=0.17818180612920753, ibnll=0.5287560483172301
# EarlyStopping counter: 2 out of 20
# it: 31, train loss=0.09295006841421127, validation loss=0.10422801226377487, c=0.6513425808093662, ibs=0.17118025872970877, ibnll=0.5114750995977011
# EarlyStopping counter: 3 out of 20
# it: 32, train loss=0.08821815997362137, validation loss=0.11331643164157867, c=0.6557648256553831, ibs=0.17479198774885707, ibnll=0.5201269007737975
# EarlyStopping counter: 4 out of 20
# it: 33, train loss=0.11187911778688431, validation loss=0.11702637374401093, c=0.6738037668617969, ibs=0.16988159489626628, ibnll=0.509648237861719
# EarlyStopping counter: 5 out of 20
# it: 34, train loss=0.11088784039020538, validation loss=0.11466611176729202, c=0.677271570374141, ibs=0.1713023807338609, ibnll=0.5144970595138024
# EarlyStopping counter: 6 out of 20
# it: 35, train loss=0.1114283874630928, validation loss=0.11296437680721283, c=0.677494273351998, ibs=0.1717882748074995, ibnll=0.5149334077869948
# EarlyStopping counter: 7 out of 20
# it: 36, train loss=0.09825772047042847, validation loss=0.10067474097013474, c=0.6730402137948588, ibs=0.1729229307510977, ibnll=0.5173615187361621
# EarlyStopping counter: 8 out of 20
# it: 37, train loss=0.08967585116624832, validation loss=0.10820803046226501, c=0.6562102316110969, ibs=0.17717804724205455, ibnll=0.5263287386649996
# Validation loss decreased (0.098365 --> 0.095517).  Saving model ...
# it: 38, train loss=0.09114741533994675, validation loss=0.09551721066236496, c=0.6587872232120132, ibs=0.1715449726218212, ibnll=0.5127960245505603
# EarlyStopping counter: 1 out of 20
# it: 39, train loss=0.08303627371788025, validation loss=0.09697722643613815, c=0.6603779587681344, ibs=0.1754378401380006, ibnll=0.5217286624060911
# EarlyStopping counter: 2 out of 20
# it: 40, train loss=0.07822751998901367, validation loss=0.09679649770259857, c=0.669826927971494, ibs=0.17031405786705933, ibnll=0.5090388090974801
# EarlyStopping counter: 3 out of 20
# it: 41, train loss=0.08750910311937332, validation loss=0.09723665565252304, c=0.6754581318401629, ibs=0.17102486147835205, ibnll=0.5106330904776777
# EarlyStopping counter: 4 out of 20
# it: 42, train loss=0.07754555344581604, validation loss=0.10461391508579254, c=0.678925935352507, ibs=0.17397101227419698, ibnll=0.5177758082937582
# EarlyStopping counter: 5 out of 20
# it: 43, train loss=0.08335642516613007, validation loss=0.09553055465221405, c=0.6812484092644439, ibs=0.1692972204742322, ibnll=0.5066263897221707
# EarlyStopping counter: 6 out of 20
# it: 44, train loss=0.08069644868373871, validation loss=0.09577598422765732, c=0.6847480274879104, ibs=0.17252516253506298, ibnll=0.5142748870241151
# Validation loss decreased (0.095517 --> 0.090227).  Saving model ...
# it: 45, train loss=0.08828890323638916, validation loss=0.0902266800403595, c=0.6853843217103589, ibs=0.17030299641624733, ibnll=0.5082637161609087
# Validation loss decreased (0.090227 --> 0.084182).  Saving model ...
# it: 46, train loss=0.09311199933290482, validation loss=0.08418234437704086, c=0.6870705013998473, ibs=0.16904614935330706, ibnll=0.5050160321735341
# EarlyStopping counter: 1 out of 20
# it: 47, train loss=0.0815209299325943, validation loss=0.09125739336013794, c=0.68802494273352, ibs=0.17253017196236176, ibnll=0.5136730817818582
# EarlyStopping counter: 2 out of 20
# it: 48, train loss=0.07921123504638672, validation loss=0.0903298631310463, c=0.6878658691779078, ibs=0.1709249289677236, ibnll=0.5095825417106222
# Validation loss decreased (0.084182 --> 0.083886).  Saving model ...
# it: 49, train loss=0.08453090488910675, validation loss=0.08388622850179672, c=0.6883430898447442, ibs=0.16877281060751845, ibnll=0.5040589124913533
# EarlyStopping counter: 1 out of 20
# it: 50, train loss=0.0810781866312027, validation loss=0.08422355353832245, c=0.6898065665563756, ibs=0.16881934046771743, ibnll=0.5040373679894959
# EarlyStopping counter: 2 out of 20
# it: 51, train loss=0.08657046407461166, validation loss=0.08462221920490265, c=0.6906019343344363, ibs=0.1704714200990996, ibnll=0.5081319377286102
# Validation loss decreased (0.083886 --> 0.083495).  Saving model ...
# it: 52, train loss=0.06964670866727829, validation loss=0.08349540084600449, c=0.6908246373122932, ibs=0.1705410187028132, ibnll=0.5081663064735289
# Validation loss decreased (0.083495 --> 0.077831).  Saving model ...
# it: 53, train loss=0.07248543202877045, validation loss=0.07783078402280807, c=0.6902519725120896, ibs=0.16861183944840963, ibnll=0.5030383932330381
# Validation loss decreased (0.077831 --> 0.077709).  Saving model ...
# it: 54, train loss=0.07637126743793488, validation loss=0.0777091458439827, c=0.690283787223212, ibs=0.16879733424910207, ibnll=0.5033177064760155
# EarlyStopping counter: 1 out of 20
# it: 55, train loss=0.07390594482421875, validation loss=0.07912907749414444, c=0.6907610078900484, ibs=0.16920180584285144, ibnll=0.504695413638269
# EarlyStopping counter: 2 out of 20
# it: 56, train loss=0.07675978541374207, validation loss=0.08284559845924377, c=0.6913973021124968, ibs=0.17206441251401167, ibnll=0.5119249865806462
# Validation loss decreased (0.077709 --> 0.077185).  Saving model ...
# it: 57, train loss=0.06948207318782806, validation loss=0.07718463242053986, c=0.6893611606006618, ibs=0.17002877106279898, ibnll=0.5059733973447254
# EarlyStopping counter: 1 out of 20
# it: 58, train loss=0.0592770054936409, validation loss=0.07835259288549423, c=0.691110969712395, ibs=0.17036079108423674, ibnll=0.5075656212849935
# EarlyStopping counter: 2 out of 20
# it: 59, train loss=0.06722103804349899, validation loss=0.07799766957759857, c=0.6911745991346399, ibs=0.1700202503560037, ibnll=0.5065425710115548
# Validation loss decreased (0.077185 --> 0.073641).  Saving model ...
# it: 60, train loss=0.08330248296260834, validation loss=0.0736406221985817, c=0.6895202341562738, ibs=0.16721231159503933, ibnll=0.49930705627957195
# EarlyStopping counter: 1 out of 20
# it: 61, train loss=0.07183101028203964, validation loss=0.07413263618946075, c=0.6898065665563756, ibs=0.16781196099551085, ibnll=0.5007655176114019
# EarlyStopping counter: 2 out of 20
# it: 62, train loss=0.08288992941379547, validation loss=0.07460834085941315, c=0.6914927462458641, ibs=0.16816930105985625, ibnll=0.5015470983307554
# EarlyStopping counter: 3 out of 20
# it: 63, train loss=0.08047927170991898, validation loss=0.0740385353565216, c=0.6913973021124968, ibs=0.16782660052089401, ibnll=0.5007716824862513
# Validation loss decreased (0.073641 --> 0.071241).  Saving model ...
# it: 64, train loss=0.059137068688869476, validation loss=0.07124140858650208, c=0.6903474166454568, ibs=0.16719860694058147, ibnll=0.4991733729244198
# EarlyStopping counter: 1 out of 20
# it: 65, train loss=0.07928532361984253, validation loss=0.07269221544265747, c=0.689679307711886, ibs=0.16804420926305907, ibnll=0.5011490242199721
# EarlyStopping counter: 2 out of 20
# it: 66, train loss=0.06677557528018951, validation loss=0.0788484662771225, c=0.6897111224230084, ibs=0.16735770296238606, ibnll=0.49988578498458547
# EarlyStopping counter: 3 out of 20
# it: 67, train loss=0.06046676263213158, validation loss=0.08181143552064896, c=0.6905383049121914, ibs=0.16768026437413877, ibnll=0.5009686956703587
# EarlyStopping counter: 4 out of 20
# it: 68, train loss=0.077987439930439, validation loss=0.08809886127710342, c=0.6925426317129041, ibs=0.17550027242641644, ibnll=0.5204425907789364
# EarlyStopping counter: 5 out of 20
# it: 69, train loss=0.07364121824502945, validation loss=0.07169772684574127, c=0.6906019343344363, ibs=0.16734901876171615, ibnll=0.49966162782291484
# EarlyStopping counter: 6 out of 20
# it: 70, train loss=0.06665681302547455, validation loss=0.07396235316991806, c=0.6909837108679053, ibs=0.16900752523209772, ibnll=0.503569926939209
# EarlyStopping counter: 7 out of 20
# it: 71, train loss=0.09068930894136429, validation loss=0.07954947650432587, c=0.6939424790022907, ibs=0.1711248988382942, ibnll=0.5093483941149562
# EarlyStopping counter: 8 out of 20
# it: 72, train loss=0.07417191565036774, validation loss=0.09044262021780014, c=0.6947378467803512, ibs=0.17731869737835657, ibnll=0.5252649497523338
# EarlyStopping counter: 9 out of 20
# it: 73, train loss=0.08177871257066727, validation loss=0.07881370931863785, c=0.6937197760244337, ibs=0.16947789164380495, ibnll=0.5058201305104764
# EarlyStopping counter: 10 out of 20
# it: 74, train loss=0.06717519462108612, validation loss=0.07756373286247253, c=0.6930198523797404, ibs=0.1678465835646634, ibnll=0.5018776949964434
# EarlyStopping counter: 11 out of 20
# it: 75, train loss=0.061988431960344315, validation loss=0.07908424735069275, c=0.6939106642911682, ibs=0.16880323330692262, ibnll=0.5036915486822051
# EarlyStopping counter: 12 out of 20
# it: 76, train loss=0.05953076854348183, validation loss=0.07301618158817291, c=0.6933061847798422, ibs=0.167381949276698, ibnll=0.5000535751814323
# EarlyStopping counter: 13 out of 20
# it: 77, train loss=0.06683987379074097, validation loss=0.0717986524105072, c=0.6928925935352507, ibs=0.1667553837939936, ibnll=0.498353868682913
# EarlyStopping counter: 14 out of 20
# it: 78, train loss=0.06941623985767365, validation loss=0.07271658629179001, c=0.6930516670908629, ibs=0.16705222271580383, ibnll=0.4991856260603419
# Validation loss decreased (0.071241 --> 0.070978).  Saving model ...
# it: 79, train loss=0.0579616017639637, validation loss=0.0709783136844635, c=0.6930198523797404, ibs=0.167549528010198, ibnll=0.5005569058822841
# EarlyStopping counter: 1 out of 20
# it: 80, train loss=0.06977083534002304, validation loss=0.07200012356042862, c=0.6934334436243319, ibs=0.16801403575437218, ibnll=0.5017724736738114
# EarlyStopping counter: 2 out of 20
# it: 81, train loss=0.07375209778547287, validation loss=0.07171991467475891, c=0.6933698142020871, ibs=0.16783165026624056, ibnll=0.5012519426673233
# Validation loss decreased (0.070978 --> 0.069263).  Saving model ...
# it: 82, train loss=0.06546061486005783, validation loss=0.0692625567317009, c=0.6929244082463731, ibs=0.16695237273670688, ibnll=0.4989482176242147
# EarlyStopping counter: 1 out of 20
# it: 83, train loss=0.07509470731019974, validation loss=0.06944720447063446, c=0.6927971494018834, ibs=0.16715586550081127, ibnll=0.49947997690139856
# EarlyStopping counter: 2 out of 20
# it: 84, train loss=0.060325924307107925, validation loss=0.07037335634231567, c=0.692765334690761, ibs=0.16766712471216533, ibnll=0.5007421901052661
# EarlyStopping counter: 3 out of 20
# it: 85, train loss=0.06223847717046738, validation loss=0.07007996737957001, c=0.6926698905573937, ibs=0.16755478439156057, ibnll=0.5003934239100252
# Validation loss decreased (0.069263 --> 0.069108).  Saving model ...
# it: 86, train loss=0.055813662707805634, validation loss=0.06910792738199234, c=0.6924153728684144, ibs=0.1672590736831206, ibnll=0.49962635869509736

# %%
print("c="+str(np.mean(np.array(odesurv_bench_vals)[:,0]))+"+-"+str(np.std(np.array(odesurv_bench_vals)[:,0])))
print("ibs="+str(np.mean(np.array(odesurv_bench_vals)[:,1]))+"+-"+str(np.std(np.array(odesurv_bench_vals)[:,1])))
print("ibnll="+str(np.mean(np.array(odesurv_bench_vals)[:,2]))+"+-"+str(np.std(np.array(odesurv_bench_vals)[:,2])))
